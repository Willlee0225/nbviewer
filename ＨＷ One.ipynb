# %%
get_ipython().magic('matplotlib inline')
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ct=-1
sum1=0
n=0
MaxVal=0 
MaxPos=0 


if n>MaxVal:
    MaxVal=n
        

    n=eval(input())

 

print(MaxVal)
# Out:
# 0
